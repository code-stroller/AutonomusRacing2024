# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the two files
path1 = 'kcity_final_parking_lot3_forward_fixed.txt'
path2 = 'kcity_final_parking_lot3_reverse_fixed.txt'

# Read the data
data1 = pd.read_csv(path1, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
data2 = pd.read_csv(path2, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])

# Ensure both paths have the same length by truncating the longer path
min_length = min(len(data1), len(data2))
data1 = data1.iloc[:min_length]
data2 = data2.iloc[:min_length]

# Define a weight for the first path
weight = 0.6

# Calculate the intermediate path, closer to the first path
mid_path = pd.DataFrame({
    'X': weight * data1['X'] + (1 - weight) * data2['X'],
    'Y': weight * data1['Y'] + (1 - weight) * data2['Y'],
    'Z': weight * data1['Z'] + (1 - weight) * data2['Z']
})

# Save the intermediate path to a txt file
# mid_path.to_csv('intermediate_path_output.txt', sep='\t', header=False, index=False)

# Plot the paths
plt.figure(figsize=(10, 8))
plt.plot(data1['X'], data1['Y'], label='Path 1', linestyle='--')
plt.plot(data2['X'], data2['Y'], label='Path 2', linestyle='--')
plt.plot(mid_path['X'], mid_path['Y'], label='Intermediate Path (Closer to Path 1)', color='purple')

# Add titles and labels
plt.title('Intermediate Path between Two Paths (Closer to Path 1)')
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\spide\AppData\Local\Temp\ipykernel_18144\3849252017.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data1 = pd.read_csv(path1, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# C:\Users\spide\AppData\Local\Temp\ipykernel_18144\3849252017.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data2 = pd.read_csv(path2, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the two files
path1 = 'kcity_final_parking_lot2_forward_fixed.txt'
path2 = 'kcity_final_parking_lot2_return_fixed.txt'
path3 = 'kcity_final_parking_lot2_reverse_fixed.txt'

# Read the data
data1 = pd.read_csv(path1, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
data2 = pd.read_csv(path2, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
data3 = pd.read_csv(path3, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])

# Ensure both paths have the same length by truncating the longer path
min_length = min(len(data1), len(data2))
data1 = data1.iloc[:min_length]
data2 = data2.iloc[:min_length]
data2 = data3.iloc[:min_length]


# Plot the paths
plt.figure(figsize=(10, 8))
plt.plot(data1['X'], data1['Y'], label='Path 1', linestyle='--')
plt.plot(data2['X'], data2['Y'], label='Path 2', linestyle='--')
plt.plot(data3['X'], data3['Y'], label='Path 3', linestyle='--')

# Add titles and labels
plt.title('Intermediate Path between Two Paths (Closer to Path 1)')
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\spide\AppData\Local\Temp\ipykernel_18144\933432024.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data1 = pd.read_csv(path1, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# C:\Users\spide\AppData\Local\Temp\ipykernel_18144\933432024.py:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data2 = pd.read_csv(path2, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# C:\Users\spide\AppData\Local\Temp\ipykernel_18144\933432024.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data3 = pd.read_csv(path3, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File paths (update with actual file locations)
file_paths = {
    'Parking Lot 1 - Forward': 'kcity_final_parking_lot1_forward_fixed.txt',
    'Parking Lot 1 - Return': 'kcity_final_parking_lot1_return_fixed.txt',
    'Parking Lot 2 - Forward': 'kcity_final_parking_lot2_forward_fixed.txt',
    'Parking Lot 2 - Return': 'kcity_final_parking_lot2_return_fixed.txt',
    'Parking Lot 3 - Forward': 'kcity_final_parking_lot3_forward_fixed.txt',
    'Parking Lot 3 - Return': 'kcity_final_parking_lot3_return_fixed.txt',
    'Park 1 - Reverse': 'kcity_park1_reverse.txt',
    'Park 2 - Reverse': 'kcity_park2_reverse.txt',
    'Park 3 - Reverse': 'kcity_park3_reverse.txt'
}

# Plotting each path on a single graph
plt.figure(figsize=(12, 10))
for label, path in file_paths.items():
    data = pd.read_csv(path, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
    plt.plot(data['X'], data['Y'], label=label)

plt.xlabel('UTM X Coordinate')
plt.ylabel('UTM Y Coordinate')
plt.title('UTM Paths Visualization')
plt.legend()
plt.grid()
plt.axis('equal')
plt.show()
# Out:
# C:\Users\spide\AppData\Local\Temp\ipykernel_16640\2298808017.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(path, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# C:\Users\spide\AppData\Local\Temp\ipykernel_16640\2298808017.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(path, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# C:\Users\spide\AppData\Local\Temp\ipykernel_16640\2298808017.py:20: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(path, delim_whitespace=True, header=None, names=['X', 'Y', 'Z'])
# ...
